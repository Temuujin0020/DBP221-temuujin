# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
attitude  = pd.read_excel(r'Бие даалт - 2.xlsx', sheet_name='Хүмүүжил хандлага')
extra_pt = pd.read_excel(r'Бие даалт - 2.xlsx', sheet_name='Нэмэлт оноо')
total = pd.read_excel(r'Бие даалт - 2.xlsx', sheet_name='Нийт')
detail = pd.read_excel(r'Бие даалт - 2.xlsx', sheet_name='Оюутнуудын нэмэлт мэдээлэл')
total = total.head(-1)

# %%
#1.“Оюутнуудын нэмэлт мэдээлэл” sheet-д тухай оюутан хэддүгээр курсэд суралцаж байгааг бодож оруулна уу.
code = pd.DataFrame(detail['Оюутны код'].str[1:3])
detail['Элссэн он'] = code.astype(int)
detail['Курс'] = detail['Элссэн он'].apply(lambda x: '6-р курс' if x == 16 
                                           else('5-р курс' if x == 17 
                                                else('4-р курс' if x == 18 
                                                     else('3-р курс' if x == 19 
                                                          else('2-р курс' if x == 20 
                                                               else('1-р курс' if x == 21 else'')))))) 
detail
# Out:
#     No  Unnamed: 1 Оюутны код       Оюутны нэр  Голч дүн  \
# 0    1         NaN  K17FF1275        Батмөнх.Д      1.94
# 1    2         NaN  K19FF1276      Оюунчимэг.Д      3.82
# 2    3         NaN  K16FF1277        Гантуяа.Б      2.73
# 3    4         NaN  K16FF1278      Энхжаргал.Д      2.61
# 4    5         NaN  K19FF1279  Нарантунгалаг.Ц      3.14
# 5    6         NaN  K17FF1280     Цэндхорлоо.П      3.37
# 6    7         NaN  K16FF1281     Даваацэцэг.М      2.88
# 7    8         NaN  K17FF1282       Батцэцэг.Л      3.44
# 8    9         NaN  K18FF1283     Адъяатамир.Т      3.81
# 9   10         NaN  K18FF1284      Гүнгэрмаа.Н      3.85
# 10  11         NaN  K19FF1285      Байгалмаа.Г      2.46
# 11  12         NaN  K19FF1286   Тайванжаргал.Ц      2.53
# 12  13         NaN  K19FF1287        Батхуяг.Б      2.57
# 13  14         NaN  K17FF1288      Ариунболд.Б      3.40
# 14  15         NaN  K17FF1289        Буманод.Б      3.69
# 15  16         NaN  K16FF1290     Нарангарав.Б      3.30
# 16  17         NaN  K18FF1291       Баттулга.Ю      2.78
# 17  18         NaN  K17FF1292     Баярсайхан.Д      3.42
# 18  19         NaN  K19FF1293       Цэндаюуш.М      2.59
# 19  20         NaN  K16FF1294           Дорж.Л      2.71
# 20  21         NaN  K16FF1295      Уранбилэг.Д      3.66
# 21  22         NaN  K18FF1296      Долгормаа.Р      2.74
# 22  23         NaN  K18FF1297         Шийжав.Г      2.97
# 23  24         NaN  K18FF1298     Эрдэнэбаяр.Г      3.11
# 24  25         NaN  K19FF1299          Хулан.Г      3.13
# 25  26         NaN  K19FF1300      Түмэнбаяр.Д      3.51
# 26  27         NaN  K18FF1301         Жимсээ.Ц      2.85
# 27  28         NaN  K18FF1302         Гансүх.Д      3.81
#
#     Судалсан хичээлийн тоо  ЭЕШ оноо Суралцаж буй мэргэжил  Элссэн он  \
# 0                       34       662                   НББ         17
# 1                       20       640                   ЭЗО         19
# 2                       38       650                   НББ         16
# 3                       37       707                    СУ         16
# 4                       21       657        АЯЛАЛ ЖУУЛЧЛАЛ         19
# 5                       36       684                  БАНК         17
# 6                       38       701                   МСМ         16
# 7                       37       687                   ЭЗО         17
# 8                       29       735                   НББ         18
# 9                       30       797                    СУ         18
# 10                      22       708        АЯЛАЛ ЖУУЛЧЛАЛ         19
# 11                      21       684                  БАНК         19
# 12                      20       667               ЭРХ ЗҮЙ         19
# 13                      41       717                    БУ         17
# 14                      39       635                   МКТ         17
# 15                      40       767                    СУ         16
# 16                      31       649        АЯЛАЛ ЖУУЛЧЛАЛ         18
# 17                      39       682                  БАНК         17
# 18                      21       749               ЭРХ ЗҮЙ         19
# 19                      40       772                    БУ         16
# 20                      41       672                   МКТ         16
# 21                      31       739               ЭРХ ЗҮЙ         18
# 22                      29       717                    БУ         18
# 23                      30       729                   МКТ         18
# 24                      22       779                   МСМ         19
# 25                      19       757                   ЭЗО         19
# 26                      33       716                   НББ         18
# 27                      31       796                    СУ         18
#
#         Курс
# 0   5-р курс
# 1   3-р курс
# 2   6-р курс
# 3   6-р курс
# 4   3-р курс
# 5   5-р курс
# 6   6-р курс
# 7   5-р курс
# 8   4-р курс
# 9   4-р курс
# 10  3-р курс
# 11  3-р курс
# 12  3-р курс
# 13  5-р курс
# 14  5-р курс
# 15  6-р курс
# 16  4-р курс
# 17  5-р курс
# 18  3-р курс
# 19  6-р курс
# 20  6-р курс
# 21  4-р курс
# 22  4-р курс
# 23  4-р курс
# 24  3-р курс
# 25  3-р курс
# 26  4-р курс
# 27  4-р курс

# %%
#2.Энгийн регресс ашиглан "шалгалтын оноо" (y) -ийг "ирцийн оноо" (x) -р тайлбарлана уу.
y0 = np.array(total['Шалгалт-30'])
x0 = np.array(total['Ирц-10'])
reg1 = 'y0~x0'
reg2 = smf.ols(reg1, total).fit()
print(reg2.summary())


#Scatter
plt.scatter(x0,y0, color = 'maroon')
z = np.polyfit(x0, y0, 1)
p = np.poly1d(z)
plt.plot(x0, p(x0))

plt.xlabel("Ирц")
plt.ylabel("Шалгалт")
plt.title("Шалгалтын оноо болон Ирцын оноо")
plt.grid()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     y0   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     78.22
# Date:                Tue, 24 May 2022   Prob (F-statistic):           2.56e-09
# Time:                        23:18:42   Log-Likelihood:                -80.235
# No. Observations:                  28   AIC:                             164.5
# Df Residuals:                      26   BIC:                             167.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -20.7378      4.726     -4.388      0.000     -30.452     -11.024
# x0             4.8740      0.551      8.844      0.000       3.741       6.007
# ==============================================================================
# Omnibus:                        1.036   Durbin-Watson:                   1.390
# Prob(Omnibus):                  0.596   Jarque-Bera (JB):                0.921
# Skew:                          -0.407   Prob(JB):                        0.631
# Kurtosis:                       2.646   Cond. No.                         49.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#3.Энгийн регресс ашиглан “Голч дүн” (y) –ийг “Судалсан хичээлийн тоо” (x) –р тайлбарлана уу.
y1 = np.array(detail['Голч дүн'])
x1 = np.array(detail['Судалсан хичээлийн тоо'])
reg3 = 'y1~x1'
reg4 = smf.ols(reg3, detail).fit()
print(reg4.summary())

#Scatter
plt.scatter(x1,y1, color = 'green')
z = np.polyfit(x1, y1, 1)
p = np.poly1d(z)
plt.plot(x1, p(x1))
plt.xlabel("Судалсан хичээлийн тоо")
plt.ylabel("Голч дүн")
plt.title("Голч дүн болон Судалсан хичээлийн тоо")
plt.grid()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     y1   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.4500
# Date:                Tue, 24 May 2022   Prob (F-statistic):              0.508
# Time:                        23:18:42   Log-Likelihood:                -19.784
# No. Observations:                  28   AIC:                             43.57
# Df Residuals:                      26   BIC:                             46.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.8317      0.412      6.868      0.000       1.984       3.679
# x1             0.0087      0.013      0.671      0.508      -0.018       0.035
# ==============================================================================
# Omnibus:                        0.277   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.870   Jarque-Bera (JB):                0.462
# Skew:                          -0.125   Prob(JB):                        0.794
# Kurtosis:                       2.422   Cond. No.                         137.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#4.“Голч дүн” болон “ЭЕШ оноо”-ний хамаарлыг ЕХБК-р үнэлэн огтлогч (B0) болон налууг (B1)-г олно уу. 
#Регрессийг графикаар дүрсэл.
y2 = np.array(detail['Голч дүн'])
x2 = np.array(detail['ЭЕШ оноо'])
reg5 = 'y2~x2'
reg6 = smf.ols(reg5, detail).fit()
print(reg6.summary())

#Scatter
plt.scatter(x2,y2, color = 'red')
z = np.polyfit(x2, y2, 1)
p = np.poly1d(z)
plt.plot(x2, p(x2))
plt.xlabel("ЭЕШ оноо")
plt.ylabel("Голч дүн")
plt.title("Голч дүн болон ЭЕШ оноо")
plt.grid()


#model formula
print(reg6.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     y2   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.9211
# Date:                Tue, 24 May 2022   Prob (F-statistic):              0.346
# Time:                        23:18:42   Log-Likelihood:                -19.536
# No. Observations:                  28   AIC:                             43.07
# Df Residuals:                      26   BIC:                             45.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7162      1.446      1.187      0.246      -1.256       4.688
# x2             0.0020      0.002      0.960      0.346      -0.002       0.006
# ==============================================================================
# Omnibus:                        1.332   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.514   Jarque-Bera (JB):                0.929
# Skew:                          -0.060   Prob(JB):                        0.628
# Kurtosis:                       2.116   Cond. No.                     1.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    1.716163
# x2           0.001953
# dtype: float64

# %%
#5.ЭЕШ-ийн оноо 620 байхад голч дүн хэд байхаар таамаглагдаж байгааг олно уу. 
onoo = 620
coef = pd.DataFrame(reg6.params).transpose()
predict = coef['Intercept'] + coef['x2'] * onoo
print('ЭЕШ-ийн оноо 620 байхад голч дүн хэд байхаар таамаглагдаж: ', predict)
# Out:
# ЭЕШ-ийн оноо 620 байхад голч дүн хэд байхаар таамаглагдаж:  0    2.92673
# dtype: float64

# %%
#6.Оюутнуудын нийт дүн баганыг ашиглан оюутан бүр багтсан Barchart үүсгэнэ үү. 
name = total['Оюутны нэр']
score = total['Нийт']
df = pd.DataFrame({'name':name,'score':score})

df.plot.bar(x = 'name', color='maroon')
plt.xlabel("Нэрс")
plt.ylabel("Оноо")
plt.title("Оюутнуудын нийт дүн")
# Out:
# Text(0.5, 1.0, 'Оюутнуудын нийт дүн')

# %%
#7.Үүсгэсэн Barchart дээр дүнгийн дундажийг харуулсан Linechart оруулна уу. 
mean = total['Нийт'].mean()
name = total['Оюутны нэр']
score = total['Нийт']
df = pd.DataFrame({'name':name,'score':score})

df.plot.bar(x = 'name', color='maroon')
plt.hlines(mean, 0, 100, color='green',label='дундаж')
plt.legend(loc='upper left')

# %%
#8.Тухайн хичээлд “A”, ”B”, ”C”, ”D”, ”F” дүн авсан оюутнуудын тоог ашиглан Piechart үүсгэнэ үү. 
total=total.fillna(' ')
data1=total.iloc[:5,:]
r=data1['Unnamed: 12']
n=data1['Unnamed: 13']
plt.pie(r,labels=n,labeldistance=1.15,autopct='%1.1f%%', wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' })
plt.show()

# %%
#9.Тухайн хичээлд мэргэжил тус бүрээс хэдэн оюутан суралцсаныг тоолж Barchart, Piechart үүсгэнэ үү. 
major = pd.DataFrame(detail['Суралцаж буй мэргэжил'].value_counts())
major.plot.bar()
plt.xlabel("Мэргэжил")
plt.ylabel("Давтамж")
plt.title("Суралцаж буй мэргэжилийн давтамж")

major.plot.pie(subplots=True, figsize=(15, 7), autopct='%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='Суралцаж буй мэргэжил'>], dtype=object)

# %%
#10.Нэмэлт ямар шинжилгээ хийх боломжтойг судлан, дурын шинжилгээ хийж үр дүнг танилцуулна уу.
#Голч дүн нь судалсан хичээлийн тоо, ЭЕШ онооноос хамаарасан олон хүчин зүйлийн шинжилгээ.
y = detail['Голч дүн']
x_1 = detail['ЭЕШ оноо']
x_2 = detail['Судалсан хичээлийн тоо']
reg10 = 'y2 ~ x_2 + x_1'
reg11 = smf.ols(reg10, detail).fit()
print(reg11.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     y2   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.7235
# Date:                Tue, 24 May 2022   Prob (F-statistic):              0.495
# Time:                        23:23:55   Log-Likelihood:                -19.236
# No. Observations:                  28   AIC:                             44.47
# Df Residuals:                      25   BIC:                             48.47
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3482      1.542      0.874      0.390      -1.827       4.524
# x_2            0.0095      0.013      0.736      0.468      -0.017       0.036
# x_1            0.0021      0.002      0.999      0.328      -0.002       0.006
# ==============================================================================
# Omnibus:                        0.340   Durbin-Watson:                   2.197
# Prob(Omnibus):                  0.844   Jarque-Bera (JB):                0.501
# Skew:                          -0.018   Prob(JB):                        0.778
# Kurtosis:                       2.346   Cond. No.                     1.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#10.Голч дүнгийн хистограмм
h = detail['Голч дүн']
plt.hist(h)
# Out:
# (array([1., 0., 1., 4., 6., 1., 3., 5., 1., 6.]),
#  array([1.94 , 2.131, 2.322, 2.513, 2.704, 2.895, 3.086, 3.277, 3.468,
#         3.659, 3.85 ]),
#  <BarContainer object of 10 artists>)
