# %%
import pandas as pd
import numpy as np

# %%
#1
xl_irts=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Ирц')
xl_seminar=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Семинар')
xl_shalgalt=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Шалгалт')
xl_biydaalt=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Бие даалт')
xl_humuujil=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Хүмүүжил хандлага')
xl_nemelt=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Нэмэлт оноо')
xl_niit=pd.read_excel('Бие даалт - 1.xlsx', sheet_name='Нийт')

# %%
#2
xl_irts=xl_irts.replace('и',0.3125)
xl_irts=xl_irts.replace('т',0)
xl_irts['Нийт -10']=xl_irts.iloc[:,4:36].sum(axis=1)

# %%
#3
xl_seminar= xl_seminar.replace(1, 25/19)
xl_seminar.fillna(0)
xl_seminar['Нийт -25']=xl_seminar.iloc[:,4:23].sum(axis=1)

# %%
#4
xl_shalgalt['Нийт']=xl_shalgalt.iloc[:,4:7].sum(axis=1)

# %%
#5 #6
xl_biydaalt['Нийт']=xl_biydaalt.iloc[:,4:6].sum(axis=1)

# %%
#7
xl_humuujil['Нийт']=xl_humuujil.iloc[:,4:8].sum(axis=1)

# %%
#8
xl_niit['Ирц-10']= xl_irts['Нийт -10']
xl_niit['Семинар-25']=xl_seminar['Нийт -25']
xl_niit['Шалгалт-30']=xl_shalgalt['Нийт']
xl_niit['Бие даалт-25']=xl_biydaalt['Нийт']
xl_niit['ХХ-10']=xl_humuujil['Нийт']
xl_niit['Нэмэлт оноо']=xl_nemelt['Нэмэлт оноо']
xl_niit['Нийт']=xl_niit.iloc[:,4:10].sum(axis=1)

# %%
#9
xl_niit = xl_niit.round(decimals = 0)
cond1 = (100 >= xl_niit['Нийт']) & (xl_niit['Нийт']>= 96)
cond2 = (95>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 90)
cond3 = (89>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 87)
cond4 = (86>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 83)
cond5 = (82>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 80)
cond6 = (79>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 77)
cond7 = (76>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 73)
cond8 = (72>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 70)
cond9 = (69>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 67)
cond10= (66>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 63)
cond11= (62>= xl_niit['Нийт']) & (xl_niit['Нийт']>= 60)
xl_niit['Unnamed: 11']= np.select([cond1, cond2, cond3, cond4, cond5, cond6, cond7, cond8, cond9, cond10, cond11],['A','A-','B+','B','B-','C+','C','C-','D+','D', 'D-'], 'F')
xl_niit
# Out:
#       No  Unnamed: 1 Оюутны код       Оюутны нэр  Ирц-10  Семинар-25  \
# 0    1.0         NaN  K17FF1275        Батмөнх.Д     6.0         4.0
# 1    2.0         NaN  K19FF1276      Оюунчимэг.Д     9.0        21.0
# 2    3.0         NaN  K16FF1277        Гантуяа.Б    10.0        25.0
# 3    4.0         NaN  K16FF1278      Энхжаргал.Д    10.0        20.0
# 4    5.0         NaN  K19FF1279  Нарантунгалаг.Ц     8.0        17.0
# 5    6.0         NaN  K17FF1280     Цэндхорлоо.П     8.0        14.0
# 6    7.0         NaN  K16FF1281     Даваацэцэг.М     8.0        20.0
# 7    8.0         NaN  K17FF1282       Батцэцэг.Л     5.0         4.0
# 8    9.0         NaN  K18FF1283     Адъяатамир.Т    10.0        25.0
# 9   10.0         NaN  K18FF1284      Гүнгэрмаа.Н     5.0         5.0
# 10  11.0         NaN  K19FF1285      Байгалмаа.Г     6.0         4.0
# 11  12.0         NaN  K19FF1286   Тайванжаргал.Ц     9.0        18.0
# 12  13.0         NaN  K19FF1287        Батхуяг.Б    10.0        25.0
# ...

# %%
#10
xl_niit=xl_niit.drop(labels=28, axis=0)
a=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'A'].count())
a2=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'A-'].count())
aa=a+a2
b1=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'B+'].count())
b2=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'B'].count())
b3=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'B-'].count())
bbb=b1+b2+b3
c1=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'C+'].count())
c2=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'C'].count())
c3=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'C-'].count())
ccc=c1+c2+c3
d1=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'D+'].count())
d2=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'D'].count())
d3=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'D-'].count())
ddd=d1+d2+d3
f=(xl_niit['Unnamed: 11'][xl_niit['Unnamed: 11'] == 'F'].count())
print('A:', aa)
print('B:', bbb)
print('C:', ccc)
print('D:', ddd)
print('F:', f)
# Out:
# A: 5
# B: 10
# C: 6
# D: 1
# F: 6
