# %%
import pandas as pnd
xl=pnd.read_excel('Store Data Sample.xlsx')
xl
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930          NaN        NaN
# 2   CA-2016-138688 2016-06-12    MO-17950          NaN        NaN
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                 Category          Product Name   Price  Quantity  Discount  \
# 0         Чихэр, печенье    Shokolinsen 250 гр  3300.0       2.0      0.00
# ...

# %%
xl.dropna(how='any',axis=1)
# Out:
#           Order ID Customer ID
# 0   CA-2016-152156    EB-13930
# 1   CA-2016-152156    EB-13930
# 2   CA-2016-138688    MO-17950
# 3   US-2015-108966    JO-15550
# 4   US-2015-108966    JO-15550
# ..             ...         ...
# 95  US-2017-109484    JR-15700
# 96  CA-2017-161018    AJ-10945
# 97  CA-2017-157833    BM-11575
# 98  CA-2016-149223    CV-12805
# 99  CA-2016-158568    DK-12835
#
# [100 rows x 2 columns]

# %%
xl.dropna(how='any',axis=0)
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 5   CA-2014-115812 2014-06-09    RH-19600     Хувь хүн    Хан-Уул
# 6   CA-2014-115812 2014-06-09    RH-19600     Хувь хүн    Хан-Уул
# 20  CA-2014-143336 2014-08-27    HL-15040     Хувь хүн    Хан-Уул
# 21  CA-2016-137330 2016-12-09    DK-13225  Байгууллага  Чингэлтэй
# 22  CA-2016-137330 2016-12-09    DK-13225  Байгууллага  Чингэлтэй
# 23  US-2017-156909 2017-07-16    CV-12805     Хувь хүн  Сүхбаатар
# 24  CA-2015-106320 2015-09-25    NS-18640     Хувь хүн    Хан-Уул
# 25  CA-2016-121755 2016-01-16    AF-10885     Хувь хүн    Хан-Уул
# 33  US-2015-150630 2015-09-17    JK-15625     Хувь хүн  Сүхбаатар
# 34  CA-2017-107727 2017-10-19    BC-11125       Гишүүн  Чингэлтэй
# ...

# %%
xl.fillna(method='bfill')
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950     Хувь хүн   Баянзүрх
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                 Category          Product Name   Price  Quantity  Discount  \
# 0         Чихэр, печенье    Shokolinsen 250 гр  3300.0       2.0      0.00
# ...

# %%
xl.fillna(method='ffill')
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950     Хувь хүн   Баянзүрх
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                 Category            Product Name   Price  Quantity  Discount  \
# 0         Чихэр, печенье      Shokolinsen 250 гр  3300.0       2.0      0.00
# ...

# %%
xl.fillna(666)
# Out:
#           Order ID           Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156  2016-11-08 00:00:00    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156  2016-11-08 00:00:00    EB-13930          666        666
# 2   CA-2016-138688  2016-06-12 00:00:00    MO-17950          666        666
# 3   US-2015-108966  2015-10-11 00:00:00    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966  2015-10-11 00:00:00    JO-15550     Хувь хүн   Баянзүрх
# ..             ...                  ...         ...          ...        ...
# 95  US-2017-109484  2017-11-06 00:00:00    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018  2017-11-09 00:00:00    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833  2017-06-17 00:00:00    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223  2016-09-06 00:00:00    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568  2016-08-29 00:00:00    DK-12835       Гишүүн  Чингэлтэй
#
# ...

# %%
xl[['Order ID']] = xl[['Order ID']].fillna(value = 'CA-2016-152156') 
xl[['Order Date']] = xl[['Order Date']].fillna(value = '2016-11-08')
xl[['Customer ID']] = xl[['Customer ID']].fillna(value = 'EB-13930')
xl[['Segment']] = xl[['Segment']].fillna(value = 'Хувь хүн')
xl[['Region']] = xl[['Region']].fillna(value = 'Хан-Уул')
xl[['Category']] = xl[['Category']].fillna(value = 'Ундаа ус') 
xl[['Product Name']] = xl[['Product Name']].fillna(value = 'Алимтай жигнэмэг 230 гр')
xl[['Price']] = xl[['Price']].fillna(value = '2200')
xl[['Quantity']] = xl[['Quantity']].fillna(value = '3')
xl[['Discount']] = xl[['Discount']].fillna(value = '0.03')
xl[['Sales']] = xl[['Sales']].fillna(value = '12222')
xl
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн    Хан-Уул
# 2   CA-2016-138688 2016-06-12    MO-17950     Хувь хүн    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                 Category             Product Name   Price Quantity Discount  \
# 0         Чихэр, печенье       Shokolinsen 250 гр  3300.0      2.0      0.0
# ...
